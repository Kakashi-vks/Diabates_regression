# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LinguisticRegression
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\ML_Project\Diabates_regression\notebooks\logostic_regression.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/d%3A/ML_Project/Diabates_regression/notebooks/logostic_regression.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/ML_Project/Diabates_regression/notebooks/logostic_regression.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/d%3A/ML_Project/Diabates_regression/notebooks/logostic_regression.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/d%3A/ML_Project/Diabates_regression/notebooks/logostic_regression.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from sklearn.preprocessing import LinguisticRegression
#
# File d:\Environments\env\Lib\site-packages\seaborn\__init__.py:2
# ...
